# %% [markdown]
# # RAG Agent
# Guided notebook for the course. Work through each checkpoint and then reproduce the final solution as a normal Python package.

# %%
import sys
sys.path.insert(0, '../src')
print('Ready')
